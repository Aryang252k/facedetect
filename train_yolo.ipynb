# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 10.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# %cd /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets
# Out:
# /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets

# %%
# !ls
# Out:
# data.yaml  pred  train	val

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
# !yolo task=detect mode=train model=yolov8n.pt data= data.yaml epochs=50 imgsz=640 plots=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 93.8MB/s]
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# it is automatically done while trannig model
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007988 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/val/labels.cache... 12 images, 0 backgrounds, 0 corrupt: 100% 12/12 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:08<00:00,  8.15s/it]
#                    all         12         12    0.00415      0.833       0.13     0.0604
#                  James         12          1    0.00746          1     0.0149     0.0119
#                   John         12          1    0.00366          1      0.995      0.398
#                 Daniel         12          1    0.00299          1      0.199      0.139
#               Benjamin         12          1      0.004          1     0.0049    0.00098
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/12 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces/Alexander.png: 640x640 1 Alexander, 297.4ms
# image 2/12 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces/Benjamin.png: 640x640 1 Benjamin, 243.8ms
# image 3/12 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces/Daniel.png: 640x640 1 Daniel, 224.9ms
# image 4/12 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces/David.png: 640x640 1 David, 212.4ms
# image 5/12 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces/James.png: 640x640 1 James, 233.7ms
# image 6/12 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/faces/John.png: 640x640 1 John, 213.7ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=pred
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/5 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/IMG-20240413-WA0006.png: 640x576 1 shidhu, 371.6ms
# image 2/5 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/h2.jpeg: 512x640 1 Michael, 335.1ms
# image 3/5 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/hrithik.png: 384x640 1 Michael, 156.8ms
# image 4/5 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/test.jpeg: 640x640 (no detections), 249.6ms
# image 5/5 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/th8.jpeg: 640x512 1 Samuel, 183.5ms
# Speed: 6.5ms preprocess, 259.3ms inference, 572.1ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict3
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=pred/IMG-20240413-WA0006.png
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/IMG-20240413-WA0006.png: 640x576 1 shidhu, 224.4ms
# Speed: 9.7ms preprocess, 224.4ms inference, 1773.7ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
/content/drive/MyDrive/Data_Science/ML-DL_projects/facedetection/datasets/pred/IMG-20240413-WA0006.png
